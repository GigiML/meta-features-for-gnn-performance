# %%
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN   --perf test_Accuracy
# Out:
# ablation: True
# Loaded 66 samples with in_dim=2122
# Target: ['test_Accuracy']
# First 5 features: ['CGSPAN_0.2_Count', 'CGSPAN_0.2_clustering_coef_kurtosis', 'CGSPAN_0.2_clustering_coef_max', 'CGSPAN_0.2_clustering_coef_mean', 'CGSPAN_0.2_clustering_coef_min']
# ablation: True
# epoch=001 train_loss=0.4947
# epoch=010 train_loss=0.0752
# epoch=020 train_loss=0.1126
# epoch=030 train_loss=0.1246
# epoch=040 train_loss=0.0304
# epoch=050 train_loss=0.0091
# epoch=060 train_loss=0.0263
# epoch=070 train_loss=0.0108
# epoch=080 train_loss=0.0169
# epoch=090 train_loss=0.0760
# epoch=100 train_loss=0.0358
# holdout train_mse=0.0209 train_mae=0.1223 train_r2=-0.4447 val_mse=0.0209 val_mae=0.1223 val_r2=-0.4447
# ablation: True
# epoch=001 train_loss=0.7572
# epoch=010 train_loss=0.1326
# epoch=020 train_loss=0.0373
# epoch=030 train_loss=0.0565
# epoch=040 train_loss=0.0534
# epoch=050 train_loss=0.0371
# epoch=060 train_loss=0.0534
# epoch=070 train_loss=0.0121
# ...

# %%
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_Accuracy  --hidden-dims 512,256,128  --mode kfold
# Out:
# ablation: True
# Loaded 66 samples with in_dim=2122
# Target: ['test_Accuracy']
# First 5 features: ['CGSPAN_0.2_Count', 'CGSPAN_0.2_clustering_coef_kurtosis', 'CGSPAN_0.2_clustering_coef_max', 'CGSPAN_0.2_clustering_coef_mean', 'CGSPAN_0.2_clustering_coef_min']
#
# --- Fold 1/10 ---
# epoch=001 train_loss=0.6320
# epoch=010 train_loss=0.0207
# epoch=020 train_loss=0.0108
# epoch=030 train_loss=0.0082
# epoch=040 train_loss=0.0065
# epoch=050 train_loss=0.0060
# epoch=060 train_loss=0.0055
# epoch=070 train_loss=0.0051
# epoch=080 train_loss=0.0047
# epoch=090 train_loss=0.0043
# epoch=100 train_loss=0.0039
# fold=1 train_mse=0.0038 train_mae=0.0443 train_r2=0.7281 val_mse=0.0480 val_mae=0.1741 val_r2=-1.6879
#
# --- Fold 2/10 ---
# epoch=001 train_loss=0.6262
# epoch=010 train_loss=0.0220
# epoch=020 train_loss=0.0106
# epoch=030 train_loss=0.0081
# epoch=040 train_loss=0.0068
# epoch=050 train_loss=0.0063
# epoch=060 train_loss=0.0058
# epoch=070 train_loss=0.0053
# ...

# %%
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_Accuracy  --hidden-dims 512,256,128  --mode loo
# Out:
# ablation: True
# Loaded 66 samples with in_dim=2122
# Target: ['test_Accuracy']
# First 5 features: ['CGSPAN_0.2_Count', 'CGSPAN_0.2_clustering_coef_kurtosis', 'CGSPAN_0.2_clustering_coef_max', 'CGSPAN_0.2_clustering_coef_mean', 'CGSPAN_0.2_clustering_coef_min']
#
# --- LOO fold 1/66 ---
# epoch=001 train_loss=0.6205
# epoch=010 train_loss=0.0642
# epoch=020 train_loss=0.0147
# epoch=030 train_loss=0.0133
# epoch=040 train_loss=0.0214
# epoch=050 train_loss=0.0400
# epoch=060 train_loss=0.0124
# epoch=070 train_loss=0.0259
# epoch=080 train_loss=0.0116
# epoch=090 train_loss=0.0186
# epoch=100 train_loss=0.0115
# loo_fold=1 train_mse=0.0185 train_mae=0.1133 train_r2=-0.3329 val_mse=0.0757 val_mae=0.2751 val_r2=nan
#
# --- LOO fold 2/66 ---
# epoch=001 train_loss=0.6278
# epoch=010 train_loss=0.0651
# epoch=020 train_loss=0.0256
# epoch=030 train_loss=0.0122
# epoch=040 train_loss=0.0388
# epoch=050 train_loss=0.0211
# epoch=060 train_loss=0.0197
# epoch=070 train_loss=0.0278
# ...

# %%
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_Accuracy  --hidden-dims 512,256,128
# Out:
# ablation: True
# Loaded 66 samples with in_dim=2122
# Target: ['test_Accuracy']
# First 5 features: ['CGSPAN_0.2_Count', 'CGSPAN_0.2_clustering_coef_kurtosis', 'CGSPAN_0.2_clustering_coef_max', 'CGSPAN_0.2_clustering_coef_mean', 'CGSPAN_0.2_clustering_coef_min']
# ablation: True
# epoch=001 train_loss=0.6151
# epoch=010 train_loss=0.0205
# epoch=020 train_loss=0.0153
# epoch=030 train_loss=0.0156
# epoch=040 train_loss=0.0103
# epoch=050 train_loss=0.0240
# epoch=060 train_loss=0.0167
# epoch=070 train_loss=0.0112
# epoch=080 train_loss=0.0365
# epoch=090 train_loss=0.0090
# epoch=100 train_loss=0.0096
# holdout train_mse=0.0102 train_mae=0.0812 train_r2=0.2923 val_mse=0.0102 val_mae=0.0812 val_r2=0.2923
# ablation: True
# epoch=001 train_loss=0.6903
# epoch=010 train_loss=0.0365
# epoch=020 train_loss=0.0320
# epoch=030 train_loss=0.0158
# epoch=040 train_loss=0.0350
# epoch=050 train_loss=0.0154
# epoch=060 train_loss=0.0213
# epoch=070 train_loss=0.0255
# ...

# %%
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_AUPRC --hidden-dims 512,256,128
# Out:
# ablation: True
# Loaded 66 samples with in_dim=2122
# Target: ['test_AUPRC']
# First 5 features: ['CGSPAN_0.2_Count', 'CGSPAN_0.2_clustering_coef_kurtosis', 'CGSPAN_0.2_clustering_coef_max', 'CGSPAN_0.2_clustering_coef_mean', 'CGSPAN_0.2_clustering_coef_min']
# ablation: True
# epoch=001 train_loss=0.4164
# epoch=010 train_loss=0.0244
# epoch=020 train_loss=0.0269
# epoch=030 train_loss=0.0095
# epoch=040 train_loss=0.0049
# epoch=050 train_loss=0.0133
# epoch=060 train_loss=0.0078
# epoch=070 train_loss=0.0107
# epoch=080 train_loss=0.0050
# epoch=090 train_loss=0.0074
# epoch=100 train_loss=0.0037
# holdout train_mse=0.0036 train_mae=0.0485 train_r2=0.4512 val_mse=0.0036 val_mae=0.0485 val_r2=0.4512
# ablation: True
# epoch=001 train_loss=0.4756
# epoch=010 train_loss=0.0499
# epoch=020 train_loss=0.0074
# epoch=030 train_loss=0.0045
# epoch=040 train_loss=0.0056
# epoch=050 train_loss=0.0056
# epoch=060 train_loss=0.0168
# epoch=070 train_loss=0.0237
# epoch=080 train_loss=0.0155
# ...

# %%
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_AUPRC --hidden-dims 512,256,128  --mode loo
# Out:
# ablation: True
# Loaded 66 samples with in_dim=2122
# Target: ['test_AUPRC']
# First 5 features: ['CGSPAN_0.2_Count', 'CGSPAN_0.2_clustering_coef_kurtosis', 'CGSPAN_0.2_clustering_coef_max', 'CGSPAN_0.2_clustering_coef_mean', 'CGSPAN_0.2_clustering_coef_min']
#
# --- LOO fold 1/66 ---
# epoch=001 train_loss=0.4149
# epoch=010 train_loss=0.0454
# epoch=020 train_loss=0.0291
# epoch=030 train_loss=0.0106
# epoch=040 train_loss=0.0180
# epoch=050 train_loss=0.0145
# epoch=060 train_loss=0.0150
# epoch=070 train_loss=0.0039
# epoch=080 train_loss=0.0125
# epoch=090 train_loss=0.0036
# epoch=100 train_loss=0.0071
# loo_fold=1 train_mse=0.0045 train_mae=0.0547 train_r2=0.0066 val_mse=0.1653 val_mae=0.4065 val_r2=nan
#
# --- LOO fold 2/66 ---
# epoch=001 train_loss=0.4214
# epoch=010 train_loss=0.0587
# epoch=020 train_loss=0.0170
# epoch=030 train_loss=0.0041
# epoch=040 train_loss=0.0063
# epoch=050 train_loss=0.0103
# epoch=060 train_loss=0.0323
# epoch=070 train_loss=0.0102
# ...

# %%
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_AUPRC --hidden-dims 512,256,128  --mode kfold
# Out:
# ablation: True
# Loaded 66 samples with in_dim=2122
# Target: ['test_AUPRC']
# First 5 features: ['CGSPAN_0.2_Count', 'CGSPAN_0.2_clustering_coef_kurtosis', 'CGSPAN_0.2_clustering_coef_max', 'CGSPAN_0.2_clustering_coef_mean', 'CGSPAN_0.2_clustering_coef_min']
#
# --- Fold 1/10 ---
# epoch=001 train_loss=0.4247
# epoch=010 train_loss=0.0167
# epoch=020 train_loss=0.0043
# epoch=030 train_loss=0.0029
# epoch=040 train_loss=0.0017
# epoch=050 train_loss=0.0014
# epoch=060 train_loss=0.0012
# epoch=070 train_loss=0.0012
# epoch=080 train_loss=0.0011
# epoch=090 train_loss=0.0010
# epoch=100 train_loss=0.0010
# fold=1 train_mse=0.0010 train_mae=0.0206 train_r2=0.7889 val_mse=0.0186 val_mae=0.0845 val_r2=0.1773
#
# --- Fold 2/10 ---
# epoch=001 train_loss=0.4307
# epoch=010 train_loss=0.0213
# epoch=020 train_loss=0.0044
# epoch=030 train_loss=0.0032
# epoch=040 train_loss=0.0016
# epoch=050 train_loss=0.0014
# epoch=060 train_loss=0.0013
# epoch=070 train_loss=0.0012
# ...

# %%
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_F1  --hidden-dims 512,256,128 
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_F1  --hidden-dims 512,256,128 --mode loo
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_F1  --hidden-dims 512,256,128 --mode kfold
# Out:
# ablation: True
# Loaded 66 samples with in_dim=2122
# Target: ['test_F1']
# First 5 features: ['CGSPAN_0.2_Count', 'CGSPAN_0.2_clustering_coef_kurtosis', 'CGSPAN_0.2_clustering_coef_max', 'CGSPAN_0.2_clustering_coef_mean', 'CGSPAN_0.2_clustering_coef_min']
# ablation: True
# epoch=001 train_loss=0.6151
# epoch=010 train_loss=0.0205
# epoch=020 train_loss=0.0153
# epoch=030 train_loss=0.0156
# epoch=040 train_loss=0.0103
# epoch=050 train_loss=0.0240
# epoch=060 train_loss=0.0167
# epoch=070 train_loss=0.0112
# epoch=080 train_loss=0.0365
# epoch=090 train_loss=0.0090
# epoch=100 train_loss=0.0096
# holdout train_mse=0.0102 train_mae=0.0812 train_r2=0.2923 val_mse=0.0102 val_mae=0.0812 val_r2=0.2923
# ablation: True
# epoch=001 train_loss=0.6903
# epoch=010 train_loss=0.0365
# epoch=020 train_loss=0.0320
# epoch=030 train_loss=0.0158
# epoch=040 train_loss=0.0350
# epoch=050 train_loss=0.0154
# epoch=060 train_loss=0.0213
# epoch=070 train_loss=0.0255
# epoch=080 train_loss=0.0132
# ...

# %%
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_AUROC --hidden-dims 512,256,128 
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_AUROC --hidden-dims 512,256,128 --mode loo
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_AUROC --hidden-dims 512,256,128  --mode kfold
# Out:
# ablation: True
# Loaded 66 samples with in_dim=2122
# Target: ['test_AUROC']
# First 5 features: ['CGSPAN_0.2_Count', 'CGSPAN_0.2_clustering_coef_kurtosis', 'CGSPAN_0.2_clustering_coef_max', 'CGSPAN_0.2_clustering_coef_mean', 'CGSPAN_0.2_clustering_coef_min']
# ablation: True
# epoch=001 train_loss=0.5617
# epoch=010 train_loss=0.0325
# epoch=020 train_loss=0.0207
# epoch=030 train_loss=0.0088
# epoch=040 train_loss=0.0125
# epoch=050 train_loss=0.0135
# epoch=060 train_loss=0.0107
# epoch=070 train_loss=0.0091
# epoch=080 train_loss=0.0159
# epoch=090 train_loss=0.0182
# epoch=100 train_loss=0.0078
# holdout train_mse=0.0065 train_mae=0.0610 train_r2=0.3436 val_mse=0.0065 val_mae=0.0610 val_r2=0.3436
# ablation: True
# epoch=001 train_loss=0.6306
# epoch=010 train_loss=0.0183
# epoch=020 train_loss=0.0469
# epoch=030 train_loss=0.0083
# epoch=040 train_loss=0.0252
# epoch=050 train_loss=0.0102
# epoch=060 train_loss=0.0114
# epoch=070 train_loss=0.0270
# epoch=080 train_loss=0.0172
# ...

# %%
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_Balanced_Acc --hidden-dims 512,256,128
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_Balanced_Acc --hidden-dims 512,256,128 --mode loo
! PYTHONPATH=. python src/tree/main_mlp.py --model GCN  --perf test_Balanced_Acc --hidden-dims 512,256,128 --mode kfold
# Out:
# ablation: True
# Loaded 66 samples with in_dim=2122
# Target: ['test_Balanced_Acc']
# First 5 features: ['CGSPAN_0.2_Count', 'CGSPAN_0.2_clustering_coef_kurtosis', 'CGSPAN_0.2_clustering_coef_max', 'CGSPAN_0.2_clustering_coef_mean', 'CGSPAN_0.2_clustering_coef_min']
# ablation: True
# epoch=001 train_loss=0.4513
# epoch=010 train_loss=0.0232
# epoch=020 train_loss=0.0214
# epoch=030 train_loss=0.0085
# epoch=040 train_loss=0.0082
# epoch=050 train_loss=0.0052
# epoch=060 train_loss=0.0049
# epoch=070 train_loss=0.0068
# epoch=080 train_loss=0.0077
# epoch=090 train_loss=0.0125
# epoch=100 train_loss=0.0082
# holdout train_mse=0.0051 train_mae=0.0571 train_r2=0.3261 val_mse=0.0051 val_mae=0.0571 val_r2=0.3261
# ablation: True
# epoch=001 train_loss=0.5149
# epoch=010 train_loss=0.0408
# epoch=020 train_loss=0.0359
# epoch=030 train_loss=0.0123
# epoch=040 train_loss=0.0097
# epoch=050 train_loss=0.0093
# epoch=060 train_loss=0.0064
# epoch=070 train_loss=0.0074
# ...
